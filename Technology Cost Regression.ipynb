# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from mpl_toolkits.mplot3d import Axes3D

# %%
data = pd.DataFrame({'SEER':[14.5, 14.5, 15, 15,15.5,15.5,16, 16, 17, 17, 17, 17, 18, 18, 18, 18, 19.5, 19.5], 
                     'Capacity':[24,36, 24,36,24,36,24,36,24,36,24,36,24,36,24,36, 24, 36], 
                     'Cost':[4598, 5464, 5931,8897,6135,7203,5944,8916,4923,5913,6121,9182,4967,5973,6244,9366, 9858, 12952], 
                     'Year':[2010,2010,2019,2019,2010,2010,2019,2019,2010,2010,2019,2019,2010,2010,2019,2019, 2021,2021]
    
    
})

X = data[['SEER', 'Capacity']].values.reshape(-1,2)
W = data['Year']
Z = data['Cost']


x = X[:,0]
y = X[:,1]
w = []
for item in W: 
    int_w = int(item)
    w.append(int_w)


z = Z

x_pred = np.linspace(10, 20, 30)   # range of SEER Values
y_pred = np.linspace(20, 40, 30)  # range of capacity Values
xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

ols = linear_model.LinearRegression()
model = ols.fit(X, Z)
predicted = model.predict(model_viz)

r2 = model.score(X,Z)

plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(x, y, z, zorder=15, linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('SEER', fontsize=12)
    ax.set_ylabel('Capacity', fontsize=12)
    ax.set_zlabel('Cost', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')

ax1.text2D(0.2, 0.32, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax1.transAxes, color='grey', alpha=0.5)
ax2.text2D(0.3, 0.42, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax2.transAxes, color='grey', alpha=0.5)
ax3.text2D(0.85, 0.85, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax3.transAxes, color='grey', alpha=0.5)

ax1.view_init(elev=10, azim=90)
ax2.view_init(elev=4, azim=114)
ax3.view_init(elev=10, azim=0)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

fig.tight_layout()

# %%
data = pd.DataFrame({'SEER':[14.5, 14.5, 15, 15,15.5,15.5,16, 16, 17, 17, 17, 17, 18, 18, 18, 18, 19.5, 19.5], 
                     'Capacity':[24,36, 24,36,24,36,24,36,24,36,24,36,24,36,24,36, 24, 36], 
                     'Cost':[4598, 5464, 5931,8897,6135,7203,5944,8916,4923,5913,6121,9182,4967,5973,6244,9366, 9858, 12952], 
                     'Year':[2010,2010,2019,2019,2010,2010,2019,2019,2010,2010,2019,2019,2010,2010,2019,2019, 2021,2021]
    
    
})

X = data[['SEER', 'Capacity']].values.reshape(-1,2)
W = data['Year']
Z = data['Cost']


x = X[:,0]
y = X[:,1]
w = []
for item in W: 
    int_w = int(item)
    w.append(int_w)


z = Z

x_pred = np.linspace(10, 20, 30)   # range of SEER Values
y_pred = np.linspace(20, 40, 30)  # range of capacity Values
xx_pred, yy_pred = np.meshgrid(x_pred, y_pred)
model_viz = np.array([xx_pred.flatten(), yy_pred.flatten()]).T

ols = linear_model.LinearRegression()
model = ols.fit(X, Z)
predicted = model.predict(model_viz)

r2 = model.score(X,Z)

plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]

for ax in axes:
    ax.plot(x, y, z, c=w, zorder=15,cmap = 'Greens',linestyle='none', marker='o', alpha=0.5)
    ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('SEER', fontsize=12)
    ax.set_ylabel('Capacity', fontsize=12)
    ax.set_zlabel('Cost', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')

ax1.text2D(0.2, 0.32, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax1.transAxes, color='grey', alpha=0.5)
ax2.text2D(0.3, 0.42, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax2.transAxes, color='grey', alpha=0.5)
ax3.text2D(0.85, 0.85, 'aegis4048.github.io', fontsize=13, ha='center', va='center',
           transform=ax3.transAxes, color='grey', alpha=0.5)

ax1.view_init(elev=10, azim=90)
ax2.view_init(elev=4, azim=114)
ax3.view_init(elev=10, azim=0)

fig.suptitle('$R^2 = %.2f$' % r2, fontsize=20)

fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-da5bfcf0ce23> in <module>
#      44
#      45 for ax in axes:
# ---> 46     ax.plot(x, y, z, c=w, zorder=15,cmap = 'Greens',linestyle='none', marker='o', alpha=0.5)
#      47     ax.scatter(xx_pred.flatten(), yy_pred.flatten(), predicted, facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
#      48     ax.set_xlabel('SEER', fontsize=12)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot(self, xs, ys, zdir, *args, **kwargs)
#    1495         zs = np.broadcast_to(zs, np.shape(xs))
#    1496
# -> 1497         lines = super().plot(xs, ys, *args, **kwargs)
#    1498         for line in lines:
#    1499             art3d.line_2d_to_3d(line, zs=zs, zdir=zdir)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
# ...
