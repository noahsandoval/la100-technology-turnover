# %%
def technology_replacement_builder():
    # Import statements
    import pandas as pd
    from itertools import repeat

    # Choose housing characteristic from buildstock to use
    technology_choice = input("Input housing characteristic (tab in LA100 Technologies file) you wish use:")

    # Create tsv array
    tsv_dict = {"tsv": [{"technology":technology_choice}]}
    
    # Create option array
    technology_df = pd.read_excel('LA100 Technologies.xlsx', sheet_name = technology_choice, index_col=0)
    #print(technology_df)
    
    technology_trans_df = technology_df.transpose()
    print(technology_trans_df)
    goal_percent = technology_trans_df.iloc[:,1]
    print(goal_percent) 
    
    
    
    
    
    
    #tech_choice = [technology_choice]
    #tsv_df = pd.DataFrame(data=tech_choice, columns = ['technology'])
    
    #tsv_dict = {"technology":technology_choice}
    
    #tsv_dict = tsv_df.to_dict()
    
   
    
    
    
    
    
    
    
    filename = technology_choice+'.json'
    filename = filename.replace(" ", "_")
    
    
 
    #option = technology_df[technology_choice]
    #print(option)

    
    
    
    
    
    #option = []
    #for col in technology_df.columns:
    #option.append(col)

    #goal = option_df["goal_percent"] = technology_trans_df.iloc[:, 2]
    #print(goal)


    # Create replacement dataframe
    #replacement_df = pd.DataFrame(data = options, columns = ['replacement'])
    
    # Create replacement matrix
    # size = len(options)
    # for option in options:
    # 	data = []
    # 	data.extend(repeat(0,size))
    # 	new_column = pd.DataFrame(data = data, columns=[options])
    # 	replacement_df[option] = new_column

    assumptions = ['#']
    assumptions_df = pd.DataFrame(data=assumptions, columns=["Assumptions:"])

    # Create output excel file
    with pd.ExcelWriter(filename) as writer:
        tsv_df.to_excel(writer, sheet_name = 'tsv', index=False)
        #option_df.to_excel(writer, sheet_name = 'option', index=False)
        #replacement_df.to_excel(writer, sheet_name = 'replacement', index=False)
        #assumptions_df.to_excel(writer, sheet_name = 'assumptions', index=False)

technology_replacement_builder()
# Out:
# Input housing characteristic (tab in LA100 Technologies file) you wish use:Cooking Range
# Cooking Range             2015      2035      diff
# Gas, 80% Usage        0.193918  0.097179 -0.096739
# Gas, 100% Usage       0.387836  0.194359 -0.193477
# Gas, 120% Usage       0.193918  0.097179 -0.096739
# Propane, 80% Usage    0.000549  0.000235 -0.000314
# Propane, 100% Usage   0.001099  0.000470 -0.000629
# Propane, 120% Usage   0.000549  0.000235 -0.000314
# Electric, 80% Usage   0.048180  0.146490  0.098310
# Electric, 100% Usage  0.096361  0.292979  0.196618
# Electric, 120% Usage  0.048180  0.146490  0.098310
# None                  0.029410  0.024385 -0.005025
# Gas, 80% Usage          0.097179
# Gas, 100% Usage         0.194359
# Gas, 120% Usage         0.097179
# Propane, 80% Usage      0.000235
# Propane, 100% Usage     0.000470
# Propane, 120% Usage     0.000235
# Electric, 80% Usage     0.146490
# Electric, 100% Usage    0.292979
# Electric, 120% Usage    0.146490
# None                    0.024385
# Name: 2035, dtype: float64
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, **kwargs)
#     627                 try:
# --> 628                     engine = config.get_option(f"io.excel.{ext}.writer")
#     629                     if engine == "auto":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     230     def __call__(self, *args, **kwds):
# --> 231         return self.__func__(*args, **kwds)
#     232
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_config/config.py in _get_option(pat, silent)
#     101 def _get_option(pat, silent=False):
# --> 102     key = _get_single_key(pat, silent)
#     103
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#      87             _warn_if_deprecated(pat)
# ---> 88         raise OptionError(f"No such keys(s): {repr(pat)}")
#      89     if len(keys) > 1:
#
# OptionError: "No such keys(s): 'io.excel.json.writer'"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-56ee86648ae5> in <module>
#      81         #assumptions_df.to_excel(writer, sheet_name = 'assumptions', index=False)
#      82
# ---> 83 technology_replacement_builder()
#
# <ipython-input-31-56ee86648ae5> in technology_replacement_builder()
#      75
#      76     # Create output excel file
# ---> 77     with pd.ExcelWriter(filename) as writer:
#      78         tsv_df.to_excel(writer, sheet_name = 'tsv', index=False)
#      79         #option_df.to_excel(writer, sheet_name = 'option', index=False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, **kwargs)
#     630                         engine = _get_default_writer(ext)
#     631                 except KeyError:
# --> 632                     raise ValueError(f"No engine for filetype: '{ext}'")
#     633             cls = get_writer(engine)
#     634
#
# ValueError: No engine for filetype: 'json'
